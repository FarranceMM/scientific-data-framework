# %%
# !pip install ipython-sql --quiet

# %%
# %reload_ext sql

# %%
from getpass import getpass
password = getpass()
# Out:
#  ········

# %%
conn_str = "mysql+pymysql://root:{}@localhost:3306/EmployeeSalary".format(password)

# %%
# %sql {conn_str}

# %%
# %sql SHOW tables;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/EmployeeSalary
# 3 rows affected.
# [('employees managers',), ('employees salary',), ('employees status',)]

# %%
# %%sql
# /* 1 Select all managers that stays in Texas? */;
#
# SELECT Manager FROM employeesalary.`employees managers`
# WHERE STATE REGEXP 'TX';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/EmployeeSalary
# 0 rows affected.
# 164 rows affected.
# [('Inocencia Wiste',),
#  ('Jerrell Baltazar',),
#  ('Dierdre Ivey',),
#  ('Amanda Bemis',),
#  ('Kimberley Proctor',),
#  ('Contessa Courser',),
#  ('Patrica Mcvay',),
#  ('Leila Lashley',),
#  ('Gricelda Lassen',),
#  ('Claretha Ahern',),
#  ('Roselia Sandoz',),
#  ('Jerry berry',),
#  ('Inocencia Wiste',),
#  ('Jerrell Baltazar',),
#  ('Dierdre Ivey',),
#  ('Amanda Bemis',),
#  ('Kimberley Proctor',),
#  ('Contessa Courser',),
#  ('Patrica Mcvay',),
#  ('Leila Lashley',),
#  ('Gricelda Lassen',),
#  ('Claretha Ahern',),
#  ('Roselia Sandoz',),
#  ('Jerry berry',),
#  ('Inocencia Wiste',),
#  ('Jerrell Baltazar',),
#  ('Dierdre Ivey',),
#  ('Amanda Bemis',),
#  ('Kimberley Proctor',),
#  ('Contessa Courser',),
#  ('Patrica Mcvay',),
#  ('Leila Lashley',),
#  ('Gricelda Lassen',),
#  ('Claretha Ahern',),
#  ('Roselia Sandoz',),
#  ('Jerry berry',),
#  ('Inocencia Wiste',),
#  ('Jerrell Baltazar',),
#  ('Dierdre Ivey',),
#  ('Amanda Bemis',),
#  ('Kimberley Proctor',),
#  ('Contessa Courser',),
#  ('Patrica Mcvay',),
#  ('Leila Lashley',),
#  ('Gricelda Lassen',),
#  ('Claretha Ahern',),
#  ('Roselia Sandoz',),
#  ('Jerry berry',),
#  ('Inocencia Wiste',),
#  ('Jerrell Baltazar',),
#  ('Dierdre Ivey',),
#  ('Amanda Bemis',),
#  ('Kimberley Proctor',),
#  ('Contessa Courser',),
#  ('Patrica Mcvay',),
#  ('Leila Lashley',),
#  ('Gricelda Lassen',),
#  ('Claretha Ahern',),
#  ('Roselia Sandoz',),
#  ('Jerry berry',),
#  ('Inocencia Wiste',),
#  ('Jerrell Baltazar',),
#  ('Dierdre Ivey',),
#  ('Amanda Bemis',),
#  ('Kimberley Proctor',),
#  ('Contessa Courser',),
#  ('Patrica Mcvay',),
#  ('Leila Lashley',),
#  ('Gricelda Lassen',),
#  ('Claretha Ahern',),
#  ('Roselia Sandoz',),
#  ('Jerry berry',),
#  ('Inocencia Wiste',),
#  ('Jerrell Baltazar',),
#  ('Dierdre Ivey',),
#  ('Amanda Bemis',),
#  ('Kimberley Proctor',),
#  ('Contessa Courser',),
#  ('Patrica Mcvay',),
#  ('Leila Lashley',),
#  ('Gricelda Lassen',),
#  ('Claretha Ahern',),
#  ('Roselia Sandoz',),
#  ('Jerry berry',),
#  ('Inocencia Wiste',),
#  ('Jerrell Baltazar',),
#  ('Dierdre Ivey',),
#  ('Amanda Bemis',),
#  ('Kimberley Proctor',),
#  ('Contessa Courser',),
#  ('Patrica Mcvay',),
#  ('Leila Lashley',),
#  ('Gricelda Lassen',),
#  ('Claretha Ahern',),
#  ('Roselia Sandoz',),
#  ('Jerry berry',),
#  ('Inocencia Wiste',),
#  ('Jerrell Baltazar',),
#  ('Dierdre Ivey',),
#  ('Amanda Bemis',),
#  ('Kimberley Proctor',),
#  ('Contessa Courser',),
#  ('Patrica Mcvay',),
#  ('Leila Lashley',),
#  ('Gricelda Lassen',),
#  ('Claretha Ahern',),
#  ('Roselia Sandoz',),
#  ('Jerry berry',),
#  ('Inocencia Wiste',),
#  ('Jerrell Baltazar',),
#  ('Dierdre Ivey',),
#  ('Amanda Bemis',),
#  ('Kimberley Proctor',),
#  ('Contessa Courser',),
#  ('Patrica Mcvay',),
#  ('Leila Lashley',),
#  ('Gricelda Lassen',),
#  ('Claretha Ahern',),
#  ('Roselia Sandoz',),
#  ('Jerry berry',),
#  ('Inocencia Wiste',),
#  ('Jerrell Baltazar',),
#  ('Dierdre Ivey',),
#  ('Amanda Bemis',),
#  ('Kimberley Proctor',),
#  ('Contessa Courser',),
#  ('Patrica Mcvay',),
#  ('',),
#  ('Gricelda Lassen',),
#  ('Claretha Ahern',),
#  ('Roselia Sandoz',),
#  ('Jerry berry',),
#  ('Inocencia Wiste',),
#  ('Jerrell Baltazar',),
#  ('Dierdre Ivey',),
#  ('',),
#  ('Kimberley Proctor',),
#  ('Contessa Courser',),
#  ('Patrica Mcvay',),
#  ('Leila Lashley',),
#  ('Gricelda Lassen',),
#  ('',),
#  ('Roselia Sandoz',),
#  ('Jerry berry',),
#  ('Inocencia Wiste',),
#  ('Jerrell Baltazar',),
#  ('Dierdre Ivey',),
#  ('Amanda Bemis',),
#  ('',),
#  ('Contessa Courser',),
#  ('Patrica Mcvay',),
#  ('',),
#  ('Gricelda Lassen',),
#  ('Claretha Ahern',),
#  ('Roselia Sandoz',),
#  ('Jerry berry',),
#  ('Inocencia Wiste',),
#  ('',),
#  ('Dierdre Ivey',),
#  ('Amanda Bemis',),
#  ('Kimberley Proctor',),
#  ('Contessa Courser',),
#  ('Patrica Mcvay',),
#  ('Leila Lashley',)]

# %%
# %%sql
# /* 2 How many managers are there in each state? */;
#
# SELECT STATE, COUNT(*) AS 'numberOfEmployees' FROM employeesalary.`employees managers`
# GROUP BY STATE;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/EmployeeSalary
# 0 rows affected.
# 6 rows affected.
# [('WA', 207), ('FL', 96), ('CA', 55), ('TX', 164), ('IL', 164), ('OH', 55)]

# %%
# %%sql
# /* 3 Who are the managers that are working fulltime? */
#
# SELECT Manager, Status FROM employeesalary.`employees managers`
# JOIN employeesalary.`employees status` ON `employees managers`.`Employee ID` = `employees status`.`Employee ID`
# WHERE Status REGEXP 'Full Time';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/EmployeeSalary
# 359 rows affected.
# [('Rebbecca Tyree', 'Full Time'),
#  ('Kate Dagenhart', 'Full Time'),
#  ('Inocencia Wiste', 'Full Time'),
#  ('Jerrell Baltazar', 'Full Time'),
#  ('Angelina Brakefield', 'Full Time'),
#  ('Jeanetta Steenbergen', 'Full Time'),
#  ('Dierdre Ivey', 'Full Time'),
#  ('Jeffry Warthen', 'Full Time'),
#  ('Frankie Haberman', 'Full Time'),
#  ('Brigid Mattos', 'Full Time'),
#  ('Angel Turnbull', 'Full Time'),
#  ('Leona Selander', 'Full Time'),
#  ('Wynell Griffeth', 'Full Time'),
#  ('Meggan Seamon', 'Full Time'),
#  ('Amanda Bemis', 'Full Time'),
#  ('Concha Hisle', 'Full Time'),
#  ('Marilynn Oxford', 'Full Time'),
#  ('Zonia Mcknight', 'Full Time'),
#  ('Breana Fravel', 'Full Time'),
#  ('Kimberley Proctor', 'Full Time'),
#  ('Contessa Courser', 'Full Time'),
#  ('Laci Rhynes', 'Full Time'),
#  ('Gricelda Lassen', 'Full Time'),
#  ('Margorie Cassidy', 'Full Time'),
#  ('Claretha Ahern', 'Full Time'),
#  ('Paul Young', 'Full Time'),
#  ('Jerry berry', 'Full Time'),
#  ('Rebbecca Tyree', 'Full Time'),
#  ('Sherron Gaumer', 'Full Time'),
#  ('Oralee Hilliker', 'Full Time'),
#  ('Vita Tores', 'Full Time'),
#  ('Kate Dagenhart', 'Full Time'),
#  ('Inocencia Wiste', 'Full Time'),
#  ('Kassie Pertuit', 'Full Time'),
#  ('Winfred Yoon', 'Full Time'),
#  ('Jerrell Baltazar', 'Full Time'),
#  ('Jeanetta Steenbergen', 'Full Time'),
#  ('Dierdre Ivey', 'Full Time'),
#  ('Jeffry Warthen', 'Full Time'),
#  ('Johnson Epting', 'Full Time'),
#  ('Angel Turnbull', 'Full Time'),
#  ('Amanda Bemis', 'Full Time'),
#  ('Concha Hisle', 'Full Time'),
#  ('Marilynn Oxford', 'Full Time'),
#  ('Isaiah Rines', 'Full Time'),
#  ('Zonia Mcknight', 'Full Time'),
#  ('Patrica Mcvay', 'Full Time'),
#  ('Leila Lashley', 'Full Time'),
#  ('Mohamed Fluellen', 'Full Time'),
#  ('Laci Rhynes', 'Full Time'),
#  ('Rebecka Kim', 'Full Time'),
#  ('Gricelda Lassen', 'Full Time'),
#  ('Claretha Ahern', 'Full Time'),
#  ('Carli Leleux', 'Full Time'),
#  ('Santo Yocom', 'Full Time'),
#  ('Roselia Sandoz', 'Full Time'),
#  ('Paul Young', 'Full Time'),
#  ('Mike Tyson', 'Full Time'),
#  ('Jerry berry', 'Full Time'),
#  ('Rebbecca Tyree', 'Full Time'),
#  ('Oralee Hilliker', 'Full Time'),
#  ('Inocencia Wiste', 'Full Time'),
#  ('Jerrell Baltazar', 'Full Time'),
#  ('Jeanetta Steenbergen', 'Full Time'),
#  ('Dierdre Ivey', 'Full Time'),
#  ('Tish Seidman', 'Full Time'),
#  ('Brigid Mattos', 'Full Time'),
#  ('Timothy Kring', 'Full Time'),
#  ('Wynell Griffeth', 'Full Time'),
#  ('Meggan Seamon', 'Full Time'),
#  ('Concha Hisle', 'Full Time'),
#  ('Marilynn Oxford', 'Full Time'),
#  ('Isaiah Rines', 'Full Time'),
#  ('Zonia Mcknight', 'Full Time'),
#  ('Contessa Courser', 'Full Time'),
#  ('Dillon Lumpkins', 'Full Time'),
#  ('Mohamed Fluellen', 'Full Time'),
#  ('Gricelda Lassen', 'Full Time'),
#  ('Marty Buettner', 'Full Time'),
#  ('Carli Leleux', 'Full Time'),
#  ('Santo Yocom', 'Full Time'),
#  ('Starla Waite', 'Full Time'),
#  ('Roselia Sandoz', 'Full Time'),
#  ('Mike Tyson', 'Full Time'),
#  ('Jerry berry', 'Full Time'),
#  ('Oralee Hilliker', 'Full Time'),
#  ('Vita Tores', 'Full Time'),
#  ('Kate Dagenhart', 'Full Time'),
#  ('Inocencia Wiste', 'Full Time'),
#  ('Kassie Pertuit', 'Full Time'),
#  ('Winfred Yoon', 'Full Time'),
#  ('Jerrell Baltazar', 'Full Time'),
#  ('Angelina Brakefield', 'Full Time'),
#  ('Jeffry Warthen', 'Full Time'),
#  ('Tish Seidman', 'Full Time'),
#  ('Angel Turnbull', 'Full Time'),
#  ('Leona Selander', 'Full Time'),
#  ('Meggan Seamon', 'Full Time'),
#  ('Concha Hisle', 'Full Time'),
#  ('Mari Acy', 'Full Time'),
#  ('Breana Fravel', 'Full Time'),
#  ('Kimberley Proctor', 'Full Time'),
#  ('Contessa Courser', 'Full Time'),
#  ('Patrica Mcvay', 'Full Time'),
#  ('Mohamed Fluellen', 'Full Time'),
#  ('Rebecka Kim', 'Full Time'),
#  ('Gricelda Lassen', 'Full Time'),
#  ('Maxie Chauez', 'Full Time'),
#  ('Margorie Cassidy', 'Full Time'),
#  ('Santo Yocom', 'Full Time'),
#  ('Starla Waite', 'Full Time'),
#  ('Paul Young', 'Full Time'),
#  ('Carl Lewis', 'Full Time'),
#  ('Oralee Hilliker', 'Full Time'),
#  ('Inocencia Wiste', 'Full Time'),
#  ('Kassie Pertuit', 'Full Time'),
#  ('Winfred Yoon', 'Full Time'),
#  ('Jerrell Baltazar', 'Full Time'),
#  ('Yuriko Du', 'Full Time'),
#  ('Graham Sparling', 'Full Time'),
#  ('Dierdre Ivey', 'Full Time'),
#  ('Johnson Epting', 'Full Time'),
#  ('Brigid Mattos', 'Full Time'),
#  ('Timothy Kring', 'Full Time'),
#  ('Angel Turnbull', 'Full Time'),
#  ('Meggan Seamon', 'Full Time'),
#  ('Amanda Bemis', 'Full Time'),
#  ('Marilynn Oxford', 'Full Time'),
#  ('Isaiah Rines', 'Full Time'),
#  ('Zonia Mcknight', 'Full Time'),
#  ('Kimberley Proctor', 'Full Time'),
#  ('Contessa Courser', 'Full Time'),
#  ('Peggy Portner', 'Full Time'),
#  ('Rebecka Kim', 'Full Time'),
#  ('Francesco Roquemore', 'Full Time'),
#  ('Maxie Chauez', 'Full Time'),
#  ('Marty Buettner', 'Full Time'),
#  ('Margorie Cassidy', 'Full Time'),
#  ('Carli Leleux', 'Full Time'),
#  ('Santo Yocom', 'Full Time'),
#  ('Starla Waite', 'Full Time'),
#  ('Roselia Sandoz', 'Full Time'),
#  ('Mike Tyson', 'Full Time'),
#  ('Jerry berry', 'Full Time'),
#  ('Oralee Hilliker', 'Full Time'),
#  ('Vita Tores', 'Full Time'),
#  ('Kassie Pertuit', 'Full Time'),
#  ('Tish Seidman', 'Full Time'),
#  ('Brigid Mattos', 'Full Time'),
#  ('Angel Turnbull', 'Full Time'),
#  ('Leona Selander', 'Full Time'),
#  ('Wynell Griffeth', 'Full Time'),
#  ('Meggan Seamon', 'Full Time'),
#  ('Concha Hisle', 'Full Time'),
#  ('Isaiah Rines', 'Full Time'),
#  ('Mari Acy', 'Full Time'),
#  ('Zonia Mcknight', 'Full Time'),
#  ('Breana Fravel', 'Full Time'),
#  ('Kimberley Proctor', 'Full Time'),
#  ('Leila Lashley', 'Full Time'),
#  ('Laci Rhynes', 'Full Time'),
#  ('Rebecka Kim', 'Full Time'),
#  ('Francesco Roquemore', 'Full Time'),
#  ('Gricelda Lassen', 'Full Time'),
#  ('Santo Yocom', 'Full Time'),
#  ('Starla Waite', 'Full Time'),
#  ('Paul Young', 'Full Time'),
#  ('Carl Lewis', 'Full Time'),
#  ('Mike Tyson', 'Full Time'),
#  ('Jerry berry', 'Full Time'),
#  ('Sherron Gaumer', 'Full Time'),
#  ('Oralee Hilliker', 'Full Time'),
#  ('Vita Tores', 'Full Time'),
#  ('Kassie Pertuit', 'Full Time'),
#  ('Jerrell Baltazar', 'Full Time'),
#  ('Yuriko Du', 'Full Time'),
#  ('Jeanetta Steenbergen', 'Full Time'),
#  ('Graham Sparling', 'Full Time'),
#  ('Jeffry Warthen', 'Full Time'),
#  ('Johnson Epting', 'Full Time'),
#  ('Tish Seidman', 'Full Time'),
#  ('Frankie Haberman', 'Full Time'),
#  ('Angel Turnbull', 'Full Time'),
#  ('Meggan Seamon', 'Full Time'),
#  ('Isaiah Rines', 'Full Time'),
#  ('Kimberley Proctor', 'Full Time'),
#  ('Contessa Courser', 'Full Time'),
#  ('Dillon Lumpkins', 'Full Time'),
#  ('Peggy Portner', 'Full Time'),
#  ('Leila Lashley', 'Full Time'),
#  ('Mohamed Fluellen', 'Full Time'),
#  ('Laci Rhynes', 'Full Time'),
#  ('Francesco Roquemore', 'Full Time'),
#  ('Gricelda Lassen', 'Full Time'),
#  ('Maxie Chauez', 'Full Time'),
#  ('Carli Leleux', 'Full Time'),
#  ('Paul Young', 'Full Time'),
#  ('Mike Tyson', 'Full Time'),
#  ('Vita Tores', 'Full Time'),
#  ('Kate Dagenhart', 'Full Time'),
#  ('Kassie Pertuit', 'Full Time'),
#  ('Winfred Yoon', 'Full Time'),
#  ('Angelina Brakefield', 'Full Time'),
#  ('Jeanetta Steenbergen', 'Full Time'),
#  ('Dierdre Ivey', 'Full Time'),
#  ('Johnson Epting', 'Full Time'),
#  ('Tish Seidman', 'Full Time'),
#  ('Frankie Haberman', 'Full Time'),
#  ('Brigid Mattos', 'Full Time'),
#  ('Angel Turnbull', 'Full Time'),
#  ('Isaiah Rines', 'Full Time'),
#  ('Kimberley Proctor', 'Full Time'),
#  ('Dillon Lumpkins', 'Full Time'),
#  ('Leila Lashley', 'Full Time'),
#  ('Laci Rhynes', 'Full Time'),
#  ('Rebecka Kim', 'Full Time'),
#  ('Gricelda Lassen', 'Full Time'),
#  ('Maxie Chauez', 'Full Time'),
#  ('Margorie Cassidy', 'Full Time'),
#  ('Starla Waite', 'Full Time'),
#  ('Jerry berry', 'Full Time'),
#  ('Kate Dagenhart', 'Full Time'),
#  ('Kassie Pertuit', 'Full Time'),
#  ('Winfred Yoon', 'Full Time'),
#  ('Jerrell Baltazar', 'Full Time'),
#  ('Yuriko Du', 'Full Time'),
#  ('Graham Sparling', 'Full Time'),
#  ('Tish Seidman', 'Full Time'),
#  ('Frankie Haberman', 'Full Time'),
#  ('Timothy Kring', 'Full Time'),
#  ('Wynell Griffeth', 'Full Time'),
#  ('Meggan Seamon', 'Full Time'),
#  ('Amanda Bemis', 'Full Time'),
#  ('Concha Hisle', 'Full Time'),
#  ('Marilynn Oxford', 'Full Time'),
#  ('Mari Acy', 'Full Time'),
#  ('Zonia Mcknight', 'Full Time'),
#  ('Kimberley Proctor', 'Full Time'),
#  ('Dillon Lumpkins', 'Full Time'),
#  ('Peggy Portner', 'Full Time'),
#  ('Leila Lashley', 'Full Time'),
#  ('Gricelda Lassen', 'Full Time'),
#  ('Maxie Chauez', 'Full Time'),
#  ('Marty Buettner', 'Full Time'),
#  ('Claretha Ahern', 'Full Time'),
#  ('Carli Leleux', 'Full Time'),
#  ('Starla Waite', 'Full Time'),
#  ('Mike Tyson', 'Full Time'),
#  ('Rebbecca Tyree', 'Full Time'),
#  ('Kate Dagenhart', 'Full Time'),
#  ('Inocencia Wiste', 'Full Time'),
#  ('Winfred Yoon', 'Full Time'),
#  ('Angelina Brakefield', 'Full Time'),
#  ('Tish Seidman', 'Full Time'),
#  ('Brigid Mattos', 'Full Time'),
#  ('Leona Selander', 'Full Time'),
#  ('Concha Hisle', 'Full Time'),
#  ('Marilynn Oxford', 'Full Time'),
#  ('Zonia Mcknight', 'Full Time'),
#  ('Breana Fravel', 'Full Time'),
#  ('Kimberley Proctor', 'Full Time'),
#  ('Dillon Lumpkins', 'Full Time'),
#  ('Patrica Mcvay', 'Full Time'),
#  ('Leila Lashley', 'Full Time'),
#  ('Maxie Chauez', 'Full Time'),
#  ('Carli Leleux', 'Full Time'),
#  ('Santo Yocom', 'Full Time'),
#  ('Roselia Sandoz', 'Full Time'),
#  ('Rebbecca Tyree', 'Full Time'),
#  ('Vita Tores', 'Full Time'),
#  ('Kate Dagenhart', 'Full Time'),
#  ('Winfred Yoon', 'Full Time'),
#  ('Jerrell Baltazar', 'Full Time'),
#  ('Yuriko Du', 'Full Time'),
#  ('', 'Full Time'),
#  ('Dierdre Ivey', 'Full Time'),
#  ('Jeffry Warthen', 'Full Time'),
#  ('Tish Seidman', 'Full Time'),
#  ('Angel Turnbull', 'Full Time'),
#  ('Wynell Griffeth', 'Full Time'),
#  ('Concha Hisle', 'Full Time'),
#  ('', 'Full Time'),
#  ('Breana Fravel', 'Full Time'),
#  ('Dillon Lumpkins', 'Full Time'),
#  ('Patrica Mcvay', 'Full Time'),
#  ('Mohamed Fluellen', 'Full Time'),
#  ('Laci Rhynes', 'Full Time'),
#  ('Rebecka Kim', 'Full Time'),
#  ('Claretha Ahern', 'Full Time'),
#  ('Carli Leleux', 'Full Time'),
#  ('Santo Yocom', 'Full Time'),
#  ('', 'Full Time'),
#  ('Mike Tyson', 'Full Time'),
#  ('Jerry berry', 'Full Time'),
#  ('Rebbecca Tyree', 'Full Time'),
#  ('Sherron Gaumer', 'Full Time'),
#  ('Kate Dagenhart', 'Full Time'),
#  ('Inocencia Wiste', 'Full Time'),
#  ('', 'Full Time'),
#  ('Graham Sparling', 'Full Time'),
#  ('Johnson Epting', 'Full Time'),
#  ('', 'Full Time'),
#  ('Brigid Mattos', 'Full Time'),
#  ('Meggan Seamon', 'Full Time'),
#  ('Concha Hisle', 'Full Time'),
#  ('Mari Acy', 'Full Time'),
#  ('', 'Full Time'),
#  ('Kimberley Proctor', 'Full Time'),
#  ('Contessa Courser', 'Full Time'),
#  ('Peggy Portner', 'Full Time'),
#  ('Leila Lashley', 'Full Time'),
#  ('Laci Rhynes', 'Full Time'),
#  ('Gricelda Lassen', 'Full Time'),
#  ('Maxie Chauez', 'Full Time'),
#  ('', 'Full Time'),
#  ('Starla Waite', 'Full Time'),
#  ('Mike Tyson', 'Full Time'),
#  ('Inocencia Wiste', 'Full Time'),
#  ('Winfred Yoon', 'Full Time'),
#  ('', 'Full Time'),
#  ('Jeanetta Steenbergen', 'Full Time'),
#  ('Dierdre Ivey', 'Full Time'),
#  ('Jeffry Warthen', 'Full Time'),
#  ('Johnson Epting', 'Full Time'),
#  ('', 'Full Time'),
#  ('Angel Turnbull', 'Full Time'),
#  ('Leona Selander', 'Full Time'),
#  ('Wynell Griffeth', 'Full Time'),
#  ('Zonia Mcknight', 'Full Time'),
#  ('', 'Full Time'),
#  ('Patrica Mcvay', 'Full Time'),
#  ('Rebecka Kim', 'Full Time'),
#  ('Francesco Roquemore', 'Full Time'),
#  ('Margorie Cassidy', 'Full Time'),
#  ('Claretha Ahern', 'Full Time'),
#  ('Carli Leleux', 'Full Time'),
#  ('Paul Young', 'Full Time'),
#  ('Carl Lewis', 'Full Time'),
#  ('Mike Tyson', 'Full Time'),
#  ('Jerry berry', 'Full Time'),
#  ('Winfred Yoon', 'Full Time'),
#  ('', 'Full Time'),
#  ('Jeanetta Steenbergen', 'Full Time'),
#  ('Dierdre Ivey', 'Full Time'),
#  ('Frankie Haberman', 'Full Time'),
#  ('Brigid Mattos', 'Full Time'),
#  ('Timothy Kring', 'Full Time'),
#  ('Angel Turnbull', 'Full Time'),
#  ('Leona Selander', 'Full Time'),
#  ('Wynell Griffeth', 'Full Time'),
#  ('Meggan Seamon', 'Full Time'),
#  ('Amanda Bemis', 'Full Time'),
#  ('Concha Hisle', 'Full Time'),
#  ('Marilynn Oxford', 'Full Time'),
#  ('Mari Acy', 'Full Time'),
#  ('Zonia Mcknight', 'Full Time'),
#  ('Breana Fravel', 'Full Time'),
#  ('Dillon Lumpkins', 'Full Time'),
#  ('Mohamed Fluellen', 'Full Time')]

# %%
# %%sql
# /* 4 Who are the managers that started working either in 2010 or 2015? */
#
# SELECT Manager, `Client Since` FROM employeesalary.`employees status`
# JOIN employeesalary.`employees managers` ON `employees status`.`Employee ID` = `employees managers`.`Employee ID`
# WHERE YEAR(`Client Since`) = 2010 OR YEAR(`Client Since`) = 2015
# ORDER BY YEAR(`Client Since`);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/EmployeeSalary
# 137 rows affected.
# [('Oralee Hilliker', '2010-08-31'),
#  ('Winfred Yoon', '2010-10-12'),
#  ('Brigid Mattos', '2010-05-05'),
#  ('Leona Selander', '2010-06-14'),
#  ('Mari Acy', '2010-02-26'),
#  ('Mohamed Fluellen', '2010-07-09'),
#  ('Kassie Pertuit', '2010-11-07'),
#  ('Angel Turnbull', '2010-02-19'),
#  ('Meggan Seamon', '2010-03-07'),
#  ('Dillon Lumpkins', '2010-05-16'),
#  ('Rebbecca Tyree', '2010-08-31'),
#  ('Kassie Pertuit', '2010-07-22'),
#  ('Frankie Haberman', '2010-02-25'),
#  ('Leona Selander', '2010-04-30'),
#  ('Kimberley Proctor', '2010-08-22'),
#  ('Peggy Portner', '2010-08-28'),
#  ('Leila Lashley', '2010-09-07'),
#  ('Gricelda Lassen', '2010-10-22'),
#  ('Wynell Griffeth', '2010-07-07'),
#  ('Meggan Seamon', '2010-07-21'),
#  ('Dillon Lumpkins', '2010-07-02'),
#  ('Claretha Ahern', '2010-08-28'),
#  ('Carli Leleux', '2010-09-19'),
#  ('Starla Waite', '2010-09-21'),
#  ('Jerrell Baltazar', '2010-10-04'),
#  ('Leona Selander', '2010-10-12'),
#  ('Laci Rhynes', '2010-12-24'),
#  ('Jerry berry', '2010-12-26'),
#  ('Vita Tores', '2010-12-26'),
#  ('Jeffry Warthen', '2010-01-08'),
#  ('Wynell Griffeth', '2010-03-19'),
#  ('Meggan Seamon', '2010-03-27'),
#  ('Rebecka Kim', '2010-04-07'),
#  ('Johnson Epting', '2010-05-14'),
#  ('Timothy Kring', '2010-07-13'),
#  ('Isaiah Rines', '2010-08-31'),
#  ('Mari Acy', '2010-09-20'),
#  ('Contessa Courser', '2010-09-10'),
#  ('Peggy Portner', '2010-10-03'),
#  ('Maxie Chauez', '2010-12-20'),
#  ('Rebbecca Tyree', '2010-03-06'),
#  ('Graham Sparling', '2010-06-08'),
#  ('Mari Acy', '2010-04-17'),
#  ('Leila Lashley', '2010-10-20'),
#  ('Rebecka Kim', '2010-06-30'),
#  ('Maxie Chauez', '2010-08-04'),
#  ('Marty Buettner', '2010-08-07'),
#  ('Paul Young', '2010-11-16'),
#  ('Inocencia Wiste', '2010-01-12'),
#  ('Margorie Cassidy', '2010-07-24'),
#  ('Yuriko Du', '2010-09-27'),
#  ('Jeanetta Steenbergen', '2010-09-29'),
#  ('Meggan Seamon', '2010-11-09'),
#  ('Concha Hisle', '2010-12-24'),
#  ('Roselia Sandoz', '2010-03-17'),
#  ('Paul Young', '2010-03-23'),
#  ('Dierdre Ivey', '2010-05-23'),
#  ('', '2010-08-07'),
#  ('Mohamed Fluellen', '2010-08-18'),
#  ('Laci Rhynes', '2010-08-25'),
#  ('Rebecka Kim', '2010-08-21'),
#  ('Mike Tyson', '2010-09-06'),
#  ('Rebbecca Tyree', '2010-10-06'),
#  ('Timothy Kring', '2010-03-12'),
#  ('Mari Acy', '2010-04-08'),
#  ('Marty Buettner', '2010-07-02'),
#  ('Margorie Cassidy', '2010-07-05'),
#  ('', '2010-07-06'),
#  ('Carli Leleux', '2010-07-21'),
#  ('Jerry berry', '2010-08-02'),
#  ('Kate Dagenhart', '2010-09-08'),
#  ('Jeanetta Steenbergen', '2010-09-24'),
#  ('Brigid Mattos', '2010-10-31'),
#  ('', '2010-12-01'),
#  ('Isaiah Rines', '2010-12-10'),
#  ('', '2010-12-15'),
#  ('Peggy Portner', '2010-12-29'),
#  ('Francesco Roquemore', '2010-01-10'),
#  ('Meggan Seamon', '2010-06-08'),
#  ('Patrica Mcvay', '2010-07-31'),
#  ('Graham Sparling', '2015-02-18'),
#  ('Johnson Epting', '2015-02-26'),
#  ('Breana Fravel', '2015-05-06'),
#  ('Contessa Courser', '2015-10-15'),
#  ('Leila Lashley', '2015-07-14'),
#  ('Carli Leleux', '2015-09-10'),
#  ('Kate Dagenhart', '2015-11-17'),
#  ('Johnson Epting', '2015-12-27'),
#  ('Brigid Mattos', '2015-02-16'),
#  ('Concha Hisle', '2015-04-12'),
#  ('Leila Lashley', '2015-05-30'),
#  ('Inocencia Wiste', '2015-07-07'),
#  ('Dierdre Ivey', '2015-01-22'),
#  ('Francesco Roquemore', '2015-10-11'),
#  ('Angel Turnbull', '2015-07-07'),
#  ('Leona Selander', '2015-07-25'),
#  ('Rebecka Kim', '2015-08-11'),
#  ('Kassie Pertuit', '2015-10-22'),
#  ('Winfred Yoon', '2015-10-23'),
#  ('Concha Hisle', '2015-11-22'),
#  ('Mohamed Fluellen', '2015-12-15'),
#  ('Frankie Haberman', '2015-06-30'),
#  ('Dillon Lumpkins', '2015-09-27'),
#  ('Patrica Mcvay', '2015-10-04'),
#  ('Gricelda Lassen', '2015-12-06'),
#  ('Dierdre Ivey', '2015-07-11'),
#  ('Angel Turnbull', '2015-11-12'),
#  ('Laci Rhynes', '2015-07-14'),
#  ('Francesco Roquemore', '2015-07-30'),
#  ('Gricelda Lassen', '2015-08-05'),
#  ('Jerrell Baltazar', '2015-02-01'),
#  ('Johnson Epting', '2015-03-18'),
#  ('Concha Hisle', '2015-06-02'),
#  ('Dillon Lumpkins', '2015-01-15'),
#  ('Leila Lashley', '2015-02-04'),
#  ('Rebecka Kim', '2015-03-29'),
#  ('Francesco Roquemore', '2015-04-21'),
#  ('Marty Buettner', '2015-06-12'),
#  ('Paul Young', '2015-08-01'),
#  ('Carl Lewis', '2015-08-21'),
#  ('Sherron Gaumer', '2015-09-03'),
#  ('Patrica Mcvay', '2015-02-04'),
#  ('Santo Yocom', '2015-03-26'),
#  ('Oralee Hilliker', '2015-03-31'),
#  ('Vita Tores', '2015-04-11'),
#  ('Tish Seidman', '2015-05-28'),
#  ('Frankie Haberman', '2015-06-02'),
#  ('', '2015-06-28'),
#  ('Carli Leleux', '2015-09-17'),
#  ('Jerry berry', '2015-10-13'),
#  ('Tish Seidman', '2015-01-29'),
#  ('Dillon Lumpkins', '2015-05-03'),
#  ('', '2015-09-13'),
#  ('', '2015-12-30'),
#  ('', '2015-03-11'),
#  ('Oralee Hilliker', '2015-03-22'),
#  ('Tish Seidman', '2015-05-17')]

# %%
# %%sql
# /* 5 What is the minimum salary for fulltime employees? */
#
# SELECT MIN(replace(Salary, '$', ' ')) AS maximumSalary FROM employeesalary.`employees salary`
# JOIN employeesalary.`employees status` ON `employees salary`.`Employee ID` = `employees salary`.`Employee ID`
# WHERE Status REGEXP 'Full Time';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/EmployeeSalary
# 1 rows affected.
# [('10 280',)]

# %%
# %%sql
# /* 6 What is the second miximum salary */
#
# SELECT MAX(Salary) AS 'secondMaxSalary' FROM employeesalary.`employees salary`
# WHERE Salary < (SELECT MAX(Salary) FROM employeesalary.`employees salary`);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/EmployeeSalary
# 1 rows affected.
# [('99 950',)]

# %%
# %%sql
# /* 7 Who are the managers that are earning more than 50 000*/
#
# UPDATE employeesalary.`employees salary` SET
# Salary = REPLACE(Salary,'$', '') WHERE Salary LIKE '$%';
#
# SELECT Manager AS 'managers', Salary AS 'salaries' FROM employeesalary.`employees managers`
# JOIN employeesalary.`employees salary` ON `employees managers`.`Employee ID` = `employees salary`.`Employee ID`
# WHERE Salary > '50000';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/EmployeeSalary
# 0 rows affected.
# 431 rows affected.
# [('Rebbecca Tyree', '70 139'),
#  ('Kate Dagenhart', '84 126'),
#  ('Inocencia Wiste', '70 266'),
#  ('Winfred Yoon', '76 902'),
#  ('Jerrell Baltazar', '86 804'),
#  ('Jeanetta Steenbergen', '57 005'),
#  ('Dierdre Ivey', '92 127'),
#  ('Jeffry Warthen', '86 447'),
#  ('Tish Seidman', '88 578'),
#  ('Frankie Haberman', '67 326'),
#  ('Brigid Mattos', '98 522'),
#  ('Angel Turnbull', '83 265'),
#  ('Wynell Griffeth', '57 015'),
#  ('Amanda Bemis', '55 272'),
#  ('Marilynn Oxford', '65 195'),
#  ('Zonia Mcknight', '59 115'),
#  ('Kimberley Proctor', '84 830'),
#  ('Contessa Courser', '53 393'),
#  ('Dillon Lumpkins', '67 148'),
#  ('Patrica Mcvay', '53 246'),
#  ('Mohamed Fluellen', '95 897'),
#  ('Laci Rhynes', '89 345'),
#  ('Francesco Roquemore', '74 372'),
#  ('Gricelda Lassen', '70 497'),
#  ('Marty Buettner', '98 732'),
#  ('Margorie Cassidy', '86 300'),
#  ('Claretha Ahern', '79 601'),
#  ('Carli Leleux', '74 456'),
#  ('Santo Yocom', '86 331'),
#  ('Starla Waite', '55 923'),
#  ('Paul Young', '57 540'),
#  ('Carl Lewis', '58 391'),
#  ('Mike Tyson', '73 164'),
#  ('Rebbecca Tyree', '99 194'),
#  ('Sherron Gaumer', '79 601'),
#  ('Inocencia Wiste', '86 247'),
#  ('Winfred Yoon', '94 857'),
#  ('Jerrell Baltazar', '89 607'),
#  ('Angelina Brakefield', '97 251'),
#  ('Graham Sparling', '91 781'),
#  ('Johnson Epting', '82 184'),
#  ('Meggan Seamon', '95 949'),
#  ('Concha Hisle', '99 246'),
#  ('Marilynn Oxford', '82 782'),
#  ('Isaiah Rines', '78 414'),
#  ('Mari Acy', '88 862'),
#  ('Zonia Mcknight', '72 524'),
#  ('Breana Fravel', '53 907'),
#  ('Dillon Lumpkins', '71 789'),
#  ('Patrica Mcvay', '89 891'),
#  ('Leila Lashley', '70 917'),
#  ('Laci Rhynes', '83 108'),
#  ('Rebecka Kim', '77 259'),
#  ('Maxie Chauez', '91 088'),
#  ('Margorie Cassidy', '68 555'),
#  ('Claretha Ahern', '88 295'),
#  ('Carli Leleux', '99 950'),
#  ('Santo Yocom', '82 152'),
#  ('Starla Waite', '53 403'),
#  ('Paul Young', '78 887'),
#  ('Jerry berry', '57 593'),
#  ('Oralee Hilliker', '79 769'),
#  ('Kate Dagenhart', '92 463'),
#  ('Inocencia Wiste', '95 288'),
#  ('Jerrell Baltazar', '92 547'),
#  ('Angelina Brakefield', '84 767'),
#  ('Jeanetta Steenbergen', '70 844'),
#  ('Graham Sparling', '74 466'),
#  ('Tish Seidman', '95 592'),
#  ('Brigid Mattos', '70 634'),
#  ('Timothy Kring', '57 887'),
#  ('Leona Selander', '87 812'),
#  ('Meggan Seamon', '86 699'),
#  ('Amanda Bemis', '69 374'),
#  ('Concha Hisle', '54 695'),
#  ('Marilynn Oxford', '91 424'),
#  ('Isaiah Rines', '77 091'),
#  ('Zonia Mcknight', '56 900'),
#  ('Patrica Mcvay', '52 941'),
#  ('Peggy Portner', '52 028'),
#  ('Rebecka Kim', '52 805'),
#  ('Marty Buettner', '82 446'),
#  ('Carli Leleux', '75 726'),
#  ('Starla Waite', '65 688'),
#  ('Carl Lewis', '74 025'),
#  ('Mike Tyson', '73 668'),
#  ('Jerry berry', '82 026'),
#  ('Sherron Gaumer', '65 751'),
#  ('Kate Dagenhart', '74 519'),
#  ('Inocencia Wiste', '84 200'),
#  ('Winfred Yoon', '95 172'),
#  ('Angelina Brakefield', '53 529'),
#  ('Jeanetta Steenbergen', '93 639'),
#  ('Dierdre Ivey', '82 226'),
#  ('Johnson Epting', '80 178'),
#  ('Tish Seidman', '52 154'),
#  ('Frankie Haberman', '59 829'),
#  ('Brigid Mattos', '98 333'),
#  ('Timothy Kring', '71 453'),
#  ('Angel Turnbull', '65 720'),
#  ('Leona Selander', '61 152'),
#  ('Wynell Griffeth', '85 460'),
#  ('Meggan Seamon', '52 553'),
#  ('Concha Hisle', '90 752'),
#  ('Marilynn Oxford', '56 406'),
#  ('Mari Acy', '88 011'),
#  ('Zonia Mcknight', '70 886'),
#  ('Contessa Courser', '79 370'),
#  ('Patrica Mcvay', '68 639'),
#  ('Peggy Portner', '69 353'),
#  ('Leila Lashley', '90 699'),
#  ('Rebecka Kim', '69 741'),
#  ('Maxie Chauez', '94 017'),
#  ('Marty Buettner', '66 318'),
#  ('Claretha Ahern', '74 424'),
#  ('Carli Leleux', '91 508'),
#  ('Paul Young', '84 483'),
#  ('Carl Lewis', '92 096'),
#  ('Jerry berry', '53 960'),
#  ('Rebbecca Tyree', '79 139'),
#  ('Sherron Gaumer', '60 953'),
#  ('Oralee Hilliker', '72 482'),
#  ('Kate Dagenhart', '72 513'),
#  ('Inocencia Wiste', '51 125'),
#  ('Kassie Pertuit', '68 051'),
#  ('Angelina Brakefield', '73 133'),
#  ('Yuriko Du', '99 635'),
#  ('Dierdre Ivey', '51 891'),
#  ('Jeffry Warthen', '55 661'),
#  ('Johnson Epting', '70 844'),
#  ('Tish Seidman', '66 528'),
#  ('Brigid Mattos', '88 463'),
#  ('Timothy Kring', '75 915'),
#  ('Leona Selander', '73 752'),
#  ('Wynell Griffeth', '97 220'),
#  ('Amanda Bemis', '54 800'),
#  ('Marilynn Oxford', '93 576'),
#  ('Isaiah Rines', '51 135'),
#  ('Mari Acy', '53 466'),
#  ('Zonia Mcknight', '84 840'),
#  ('Breana Fravel', '88 841'),
#  ('Contessa Courser', '64 050'),
#  ('Leila Lashley', '65 972'),
#  ('Laci Rhynes', '52 868'),
#  ('Rebecka Kim', '69 626'),
#  ('Francesco Roquemore', '70 634'),
#  ('Gricelda Lassen', '82 835'),
#  ('Maxie Chauez', '79 412'),
#  ('Claretha Ahern', '66 717'),
#  ('Santo Yocom', '76 251'),
#  ('Starla Waite', '74 078'),
#  ('Roselia Sandoz', '54 684'),
#  ('Carl Lewis', '68 534'),
#  ('Mike Tyson', '90 290'),
#  ('Jerry berry', '94 689'),
#  ('Vita Tores', '72 849'),
#  ('Inocencia Wiste', '78 845'),
#  ('Winfred Yoon', '83 769'),
#  ('Jeanetta Steenbergen', '52 469'),
#  ('Graham Sparling', '87 119'),
#  ('Jeffry Warthen', '92 789'),
#  ('Johnson Epting', '57 215'),
#  ('Tish Seidman', '86 772'),
#  ('Frankie Haberman', '52 038'),
#  ('Brigid Mattos', '82 047'),
#  ('Angel Turnbull', '77 448'),
#  ('Wynell Griffeth', '69 416'),
#  ('Meggan Seamon', '76 734'),
#  ('Mari Acy', '79 790'),
#  ('Zonia Mcknight', '62 643'),
#  ('Breana Fravel', '53 393'),
#  ('Kimberley Proctor', '80 073'),
#  ('Patrica Mcvay', '53 876'),
#  ('Peggy Portner', '61 152'),
#  ('Leila Lashley', '52 532'),
#  ('Laci Rhynes', '68 523'),
#  ('Rebecka Kim', '80 882'),
#  ('Gricelda Lassen', '77 711'),
#  ('Marty Buettner', '74 183'),
#  ('Margorie Cassidy', '82 971'),
#  ('Starla Waite', '84 399'),
#  ('Roselia Sandoz', '76 251'),
#  ('Jerry berry', '86 835'),
#  ('Sherron Gaumer', '81 732'),
#  ('Oralee Hilliker', '70 529'),
#  ('Vita Tores', '82 572'),
#  ('Kate Dagenhart', '93 198'),
#  ('Angelina Brakefield', '71 484'),
#  ('Yuriko Du', '68 313'),
#  ('Dierdre Ivey', '86 048'),
#  ('Jeffry Warthen', '62 223'),
#  ('Johnson Epting', '82 467'),
#  ('Tish Seidman', '72 471'),
#  ('Timothy Kring', '55 104'),
#  ('Angel Turnbull', '52 280'),
#  ('Leona Selander', '55 010'),
#  ('Meggan Seamon', '56 585'),
#  ('Isaiah Rines', '52 185'),
#  ('Zonia Mcknight', '62 223'),
#  ('Kimberley Proctor', '94 847'),
#  ('Contessa Courser', '54 999'),
#  ('Dillon Lumpkins', '69 951'),
#  ('Peggy Portner', '99 960'),
#  ('Leila Lashley', '94 301'),
#  ('Mohamed Fluellen', '53 172'),
#  ('Laci Rhynes', '60 627'),
#  ('Rebecka Kim', '66 444'),
#  ('Gricelda Lassen', '85 397'),
#  ('Maxie Chauez', '77 301'),
#  ('Marty Buettner', '81 407'),
#  ('Margorie Cassidy', '57 981'),
#  ('Carli Leleux', '75 369'),
#  ('Santo Yocom', '56 364'),
#  ('Roselia Sandoz', '86 016'),
#  ('Paul Young', '87 528'),
#  ('Carl Lewis', '66 486'),
#  ('Mike Tyson', '59 388'),
#  ('Jerry berry', '94 637'),
#  ('Rebbecca Tyree', '73 752'),
#  ('Inocencia Wiste', '55 314'),
#  ('Winfred Yoon', '51 083'),
#  ('Jerrell Baltazar', '54 632'),
#  ('Angelina Brakefield', '57 488'),
#  ('Graham Sparling', '90 017'),
#  ('Jeffry Warthen', '62 591'),
#  ('Tish Seidman', '82 961'),
#  ('Brigid Mattos', '52 500'),
#  ('Timothy Kring', '57 068'),
#  ('Angel Turnbull', '56 081'),
#  ('Wynell Griffeth', '85 502'),
#  ('Meggan Seamon', '90 206'),
#  ('Concha Hisle', '86 741'),
#  ('Marilynn Oxford', '83 717'),
#  ('Mari Acy', '99 876'),
#  ('Kimberley Proctor', '79 023'),
#  ('Dillon Lumpkins', '71 820'),
#  ('Peggy Portner', '82 814'),
#  ('Leila Lashley', '72 986'),
#  ('Mohamed Fluellen', '51 776'),
#  ('Gricelda Lassen', '92 138'),
#  ('Marty Buettner', '89 912'),
#  ('Margorie Cassidy', '72 860'),
#  ('Carli Leleux', '54 359'),
#  ('Santo Yocom', '97 367'),
#  ('Starla Waite', '79 149'),
#  ('Paul Young', '84 357'),
#  ('Carl Lewis', '73 154'),
#  ('Mike Tyson', '77 060'),
#  ('Jerry berry', '86 090'),
#  ('Kassie Pertuit', '93 419'),
#  ('Winfred Yoon', '77 207'),
#  ('Jerrell Baltazar', '71 001'),
#  ('Yuriko Du', '99 561'),
#  ('Jeanetta Steenbergen', '55 167'),
#  ('Graham Sparling', '92 505'),
#  ('Tish Seidman', '87 056'),
#  ('Frankie Haberman', '54 191'),
#  ('Wynell Griffeth', '78 561'),
#  ('Meggan Seamon', '77 658'),
#  ('Amanda Bemis', '58 895'),
#  ('Marilynn Oxford', '90 038'),
#  ('Isaiah Rines', '62 370'),
#  ('Mari Acy', '82 856'),
#  ('Breana Fravel', '56 679'),
#  ('Dillon Lumpkins', '80 157'),
#  ('Leila Lashley', '89 775'),
#  ('Rebecka Kim', '51 471'),
#  ('Francesco Roquemore', '94 175'),
#  ('Marty Buettner', '51 545'),
#  ('Claretha Ahern', '70 634'),
#  ('Starla Waite', '72 072'),
#  ('Paul Young', '54 968'),
#  ('Carl Lewis', '69 941'),
#  ('Mike Tyson', '53 550'),
#  ('Rebbecca Tyree', '74 298'),
#  ('Sherron Gaumer', '53 571'),
#  ('Oralee Hilliker', '84 536'),
#  ('Inocencia Wiste', '70 844'),
#  ('Kassie Pertuit', '72 408'),
#  ('Jerrell Baltazar', '56 249'),
#  ('Angelina Brakefield', '99 908'),
#  ('Graham Sparling', '83 906'),
#  ('Dierdre Ivey', '73 080'),
#  ('Jeffry Warthen', '57 215'),
#  ('Frankie Haberman', '65 436'),
#  ('Brigid Mattos', '85 176'),
#  ('Angel Turnbull', '66 980'),
#  ('Leona Selander', '55 829'),
#  ('Wynell Griffeth', '69 384'),
#  ('Meggan Seamon', '85 281'),
#  ('Amanda Bemis', '91 686'),
#  ('Concha Hisle', '73 280'),
#  ('Marilynn Oxford', '54 684'),
#  ('Isaiah Rines', '70 949'),
#  ('Zonia Mcknight', '80 189'),
#  ('Dillon Lumpkins', '55 535'),
#  ('Patrica Mcvay', '89 796'),
#  ('Peggy Portner', '88 788'),
#  ('Leila Lashley', '83 969'),
#  ('Mohamed Fluellen', '69 384'),
#  ('Rebecka Kim', '82 352'),
#  ('Gricelda Lassen', '76 136'),
#  ('Maxie Chauez', '88 841'),
#  ('Margorie Cassidy', '66 623'),
#  ('Claretha Ahern', '57 015'),
#  ('Carli Leleux', '53 267'),
#  ('Santo Yocom', '62 948'),
#  ('Starla Waite', '72 408'),
#  ('Jerry berry', '71 127'),
#  ('Rebbecca Tyree', '68 324'),
#  ('Oralee Hilliker', '60 932'),
#  ('Vita Tores', '91 707'),
#  ('Kate Dagenhart', '58 412'),
#  ('Inocencia Wiste', '52 847'),
#  ('Kassie Pertuit', '54 894'),
#  ('Winfred Yoon', '63 042'),
#  ('Angelina Brakefield', '52 637'),
#  ('Yuriko Du', '73 007'),
#  ('Jeanetta Steenbergen', '99 309'),
#  ('', '52 091'),
#  ('Dierdre Ivey', '76 094'),
#  ('Jeffry Warthen', '62 591'),
#  ('Johnson Epting', '67 746'),
#  ('Tish Seidman', '82 793'),
#  ('Frankie Haberman', '58 727'),
#  ('', '51 660'),
#  ('Angel Turnbull', '51 975'),
#  ('Wynell Griffeth', '51 576'),
#  ('', '63 336'),
#  ('Mari Acy', '72 734'),
#  ('Zonia Mcknight', '99 446'),
#  ('Contessa Courser', '95 277'),
#  ('Dillon Lumpkins', '96 695'),
#  ('Patrica Mcvay', '83 234'),
#  ('', '62 685'),
#  ('Mohamed Fluellen', '52 112'),
#  ('Laci Rhynes', '77 186'),
#  ('Maxie Chauez', '61 583'),
#  ('Margorie Cassidy', '74 603'),
#  ('Claretha Ahern', '92 705'),
#  ('Carli Leleux', '75 737'),
#  ('Santo Yocom', '90 920'),
#  ('', '67 473'),
#  ('Carl Lewis', '99 257'),
#  ('Jerry berry', '79 086'),
#  ('Rebbecca Tyree', '95 519'),
#  ('Sherron Gaumer', '81 176'),
#  ('Oralee Hilliker', '89 817'),
#  ('Inocencia Wiste', '79 926'),
#  ('Angelina Brakefield', '53 886'),
#  ('', '62 601'),
#  ('Graham Sparling', '77 417'),
#  ('Dierdre Ivey', '54 033'),
#  ('Jeffry Warthen', '56 301'),
#  ('Johnson Epting', '84 966'),
#  ('Tish Seidman', '78 456'),
#  ('', '91 193'),
#  ('Brigid Mattos', '99 614'),
#  ('Angel Turnbull', '70 224'),
#  ('Leona Selander', '52 994'),
#  ('Wynell Griffeth', '54 695'),
#  ('Isaiah Rines', '72 807'),
#  ('Zonia Mcknight', '68 208'),
#  ('', '91 959'),
#  ('Kimberley Proctor', '77 858'),
#  ('Dillon Lumpkins', '72 828'),
#  ('Patrica Mcvay', '64 323'),
#  ('Peggy Portner', '56 007'),
#  ('Leila Lashley', '76 745'),
#  ('', '63 347'),
#  ('Laci Rhynes', '62 255'),
#  ('Maxie Chauez', '55 734'),
#  ('Marty Buettner', '81 029'),
#  ('Margorie Cassidy', '73 101'),
#  ('', '53 613'),
#  ('Carli Leleux', '74 225'),
#  ('Santo Yocom', '52 017'),
#  ('Paul Young', '64 124'),
#  ('', '53 582'),
#  ('Sherron Gaumer', '67 284'),
#  ('Oralee Hilliker', '93 251'),
#  ('', '53 771'),
#  ('Winfred Yoon', '89 723'),
#  ('Jerrell Baltazar', '57 677'),
#  ('', '72 839'),
#  ('Graham Sparling', '56 690'),
#  ('Dierdre Ivey', '85 302'),
#  ('Jeffry Warthen', '83 129'),
#  ('Johnson Epting', '90 920'),
#  ('Angel Turnbull', '75 453'),
#  ('', '87 266'),
#  ('Isaiah Rines', '90 773'),
#  ('Zonia Mcknight', '71 442'),
#  ('', '89 093'),
#  ('', '91 686'),
#  ('Contessa Courser', '54 611'),
#  ('', '68 303'),
#  ('Patrica Mcvay', '72 513'),
#  ('Peggy Portner', '57 225'),
#  ('Mohamed Fluellen', '52 101'),
#  ('Rebecka Kim', '67 421'),
#  ('Marty Buettner', '56 700'),
#  ('Margorie Cassidy', '55 461'),
#  ('Santo Yocom', '81 197'),
#  ('Carl Lewis', '74 466'),
#  ('Mike Tyson', '69 647'),
#  ('', '72 167'),
#  ('Oralee Hilliker', '70 613'),
#  ('Inocencia Wiste', '53 256'),
#  ('', '55 923'),
#  ('Jeanetta Steenbergen', '51 440'),
#  ('Dierdre Ivey', '95 141'),
#  ('Jeffry Warthen', '99 383'),
#  ('Johnson Epting', '73 479'),
#  ('Tish Seidman', '66 413'),
#  ('Timothy Kring', '55 020'),
#  ('Angel Turnbull', '68 712'),
#  ('Leona Selander', '80 294'),
#  ('Wynell Griffeth', '74 823'),
#  ('Meggan Seamon', '99 708'),
#  ('Amanda Bemis', '55 766'),
#  ('Concha Hisle', '93 954'),
#  ('Marilynn Oxford', '79 538'),
#  ('Isaiah Rines', '53 792'),
#  ('Mari Acy', '81 701'),
#  ('Breana Fravel', '73 542'),
#  ('Kimberley Proctor', '98 774'),
#  ('Contessa Courser', '76 388'),
#  ('Patrica Mcvay', '70 182'),
#  ('Leila Lashley', '74 760'),
#  ('Mohamed Fluellen', '53 918')]

# %%
# %%sql
# /* 8 How many managers that are earning less than 50000 */
#
# SELECT COUNT(Manager) FROM employeesalary.`employees managers`
# JOIN employeesalary.`employees salary` ON `employees managers`.`Employee ID` = `employees salary`.`Employee ID`
# WHERE Salary < '50000';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/EmployeeSalary
# 1 rows affected.
# [(312,)]

# %%
# %%sql
# /* 9 What is the average salary from each state */
#
# SELECT STATE, ROUND(avg(Salary), 2) AS 'avgSalary' FROM employeesalary.`employees salary`
# JOIN employeesalary.`employees managers` ON `employees salary`.`Employee ID` = `employees managers`.`Employee ID`
# GROUP BY STATE;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/EmployeeSalary
# 6 rows affected.
# [('WA', 59.96),
#  ('FL', 54.89),
#  ('CA', 60.8),
#  ('TX', 57.52),
#  ('IL', 59.35),
#  ('OH', 57.69)]

# %%
# %%sql
# /* 10 Which employee has the lowest salary */
#
# SELECT Manager AS 'Manager', Salary AS minSalary FROM employeesalary.`employees managers`
# JOIN employeesalary.`employees salary` ON `employees managers`.`Employee ID` = `employees salary`.`Employee ID`
# ORDER BY Salary ASC LIMIT 1;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/EmployeeSalary
# 1 rows affected.
# [('Frankie Haberman', '10 280')]

# %%
# %%sql
# /* 11 What is the median salary of all the employees */
#
# SELECT MAX(Salary) AS "Median"
# FROM (SELECT Salary,
# NTILE(4) OVER(ORDER BY Salary) AS Quartile
#  FROM employeesalary.`employees salary`
# ) employeesalary
# WHERE Quartile = 2;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/EmployeeSalary
# 1 rows affected.
# [('54 800',)]

# %%
# %%sql
# /* 12 Mention all the States and their highest paid managers and their salary */
#
# SELECT STATE, Manager, max(Salary) AS 'salaries' FROM employeesalary.`employees managers`
# JOIN employeesalary.`employees salary` ON `employees managers`.`Employee ID` = `employees salary`.`Employee ID`
# GROUP BY STATE, Manager;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/EmployeeSalary
# 59 rows affected.
# [('WA', 'Rebbecca Tyree', '99 194'),
#  ('WA', 'Sherron Gaumer', '81 732'),
#  ('WA', 'Oralee Hilliker', '93 251'),
#  ('FL', 'Vita Tores', '91 707'),
#  ('CA', 'Kate Dagenhart', '93 198'),
#  ('TX', 'Inocencia Wiste', '95 288'),
#  ('FL', 'Kassie Pertuit', '93 419'),
#  ('IL', 'Winfred Yoon', '95 172'),
#  ('TX', 'Jerrell Baltazar', '92 547'),
#  ('FL', 'Angelina Brakefield', '99 908'),
#  ('IL', 'Yuriko Du', '99 635'),
#  ('IL', 'Jeanetta Steenbergen', '99 309'),
#  ('IL', 'Graham Sparling', '92 505'),
#  ('TX', 'Dierdre Ivey', '95 141'),
#  ('CA', 'Jeffry Warthen', '99 383'),
#  ('OH', 'Johnson Epting', '90 920'),
#  ('WA', 'Tish Seidman', '95 592'),
#  ('WA', 'Frankie Haberman', '67 326'),
#  ('OH', 'Brigid Mattos', '99 614'),
#  ('WA', 'Timothy Kring', '75 915'),
#  ('FL', 'Angel Turnbull', '83 265'),
#  ('CA', 'Leona Selander', '87 812'),
#  ('IL', 'Wynell Griffeth', '97 220'),
#  ('WA', 'Meggan Seamon', '99 708'),
#  ('TX', 'Amanda Bemis', '91 686'),
#  ('FL', 'Concha Hisle', '99 246'),
#  ('WA', 'Marilynn Oxford', '93 576'),
#  ('WA', 'Isaiah Rines', '90 773'),
#  ('IL', 'Mari Acy', '99 876'),
#  ('WA', 'Zonia Mcknight', '99 446'),
#  ('WA', 'Breana Fravel', '88 841'),
#  ('TX', 'Kimberley Proctor', '98 774'),
#  ('TX', 'Contessa Courser', '95 277'),
#  ('OH', 'Dillon Lumpkins', '96 695'),
#  ('TX', 'Patrica Mcvay', '89 891'),
#  ('IL', 'Peggy Portner', '99 960'),
#  ('TX', 'Leila Lashley', '94 301'),
#  ('WA', 'Mohamed Fluellen', '95 897'),
#  ('IL', 'Laci Rhynes', '89 345'),
#  ('CA', 'Rebecka Kim', '82 352'),
#  ('OH', 'Francesco Roquemore', '94 175'),
#  ('TX', 'Gricelda Lassen', '92 138'),
#  ('IL', 'Maxie Chauez', '94 017'),
#  ('IL', 'Marty Buettner', '98 732'),
#  ('FL', 'Margorie Cassidy', '86 300'),
#  ('TX', 'Claretha Ahern', '92 705'),
#  ('FL', 'Carli Leleux', '99 950'),
#  ('IL', 'Santo Yocom', '97 367'),
#  ('WA', 'Starla Waite', '84 399'),
#  ('TX', 'Roselia Sandoz', '86 016'),
#  ('WA', 'Paul Young', '87 528'),
#  ('WA', 'Carl Lewis', '99 257'),
#  ('IL', 'Mike Tyson', '90 290'),
#  ('TX', 'Jerry berry', '94 689'),
#  ('IL', '', '62 601'),
#  ('OH', '', '68 303'),
#  ('WA', '', '91 959'),
#  ('TX', '', '91 686'),
#  ('FL', '', '72 839')]

# %%
# %%sql
# /* 13 How many salaries that are duplicated */
#
# SELECT Salary, COUNT(Salary) AS duplicatedSalary FROM employeesalary.`employees salary`
# GROUP BY Salary
# HAVING COUNT(Salary) > 1;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/EmployeeSalary
# 32 rows affected.
# [('12 285', 2),
#  ('57 015', 2),
#  ('53 393', 2),
#  ('55 923', 2),
#  ('36 866', 2),
#  ('27 216', 2),
#  ('70 844', 3),
#  ('74 466', 2),
#  ('70 634', 3),
#  ('54 695', 2),
#  ('30 450', 2),
#  ('29 022', 2),
#  ('45 833', 2),
#  ('61 152', 2),
#  ('25 032', 2),
#  ('40 961', 3),
#  ('72 513', 2),
#  ('30 251', 2),
#  ('73 752', 2),
#  ('88 841', 2),
#  ('76 251', 2),
#  ('54 684', 2),
#  ('47 292', 2),
#  ('57 215', 2),
#  ('62 223', 2),
#  ('36 110', 2),
#  ('62 591', 2),
#  ('72 408', 2),
#  ('69 384', 2),
#  ('91 686', 2),
#  ('45 045', 2),
#  ('90 920', 2)]

# %%
# %%sql
# /* 14 How many employees that did not receive their bonuses */
#
# SELECT COUNT(Manager) FROM employeesalary.`employees managers`
# JOIN employeesalary.`employees salary` ON `employees managers`.`Employee ID` = `employees salary`.`Employee ID`
# WHERE Bonus IS NULL;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/EmployeeSalary
# 1 rows affected.
# [(0,)]

# %%
# %%sql
# /* 15 Show all employees whose bonuses are between 10 to 50% */
#
# SELECT manager FROM employeesalary.`employees managers`
# JOIN employeesalary.`employees salary` ON `employees managers`.`Employee ID` = `employees salary`.`Employee ID`
# WHERE bonus BETWEEN 12 AND 20;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/EmployeeSalary
# 132 rows affected.
# [('Jerrell Baltazar',),
#  ('Dierdre Ivey',),
#  ('Jeffry Warthen',),
#  ('Tish Seidman',),
#  ('Brigid Mattos',),
#  ('Mohamed Fluellen',),
#  ('Laci Rhynes',),
#  ('Marty Buettner',),
#  ('Margorie Cassidy',),
#  ('Santo Yocom',),
#  ('Rebbecca Tyree',),
#  ('Inocencia Wiste',),
#  ('Winfred Yoon',),
#  ('Jerrell Baltazar',),
#  ('Angelina Brakefield',),
#  ('Yuriko Du',),
#  ('Graham Sparling',),
#  ('Jeffry Warthen',),
#  ('Frankie Haberman',),
#  ('Meggan Seamon',),
#  ('Concha Hisle',),
#  ('Mari Acy',),
#  ('Patrica Mcvay',),
#  ('Maxie Chauez',),
#  ('Claretha Ahern',),
#  ('Carli Leleux',),
#  ('Kate Dagenhart',),
#  ('Inocencia Wiste',),
#  ('Jerrell Baltazar',),
#  ('Jeffry Warthen',),
#  ('Tish Seidman',),
#  ('Leona Selander',),
#  ('Meggan Seamon',),
#  ('Marilynn Oxford',),
#  ('Winfred Yoon',),
#  ('Jeanetta Steenbergen',),
#  ('Graham Sparling',),
#  ('Jeffry Warthen',),
#  ('Brigid Mattos',),
#  ('Wynell Griffeth',),
#  ('Concha Hisle',),
#  ('Mari Acy',),
#  ('Kimberley Proctor',),
#  ('Leila Lashley',),
#  ('Maxie Chauez',),
#  ('Carli Leleux',),
#  ('Carl Lewis',),
#  ('Yuriko Du',),
#  ('Brigid Mattos',),
#  ('Wynell Griffeth',),
#  ('Marilynn Oxford',),
#  ('Breana Fravel',),
#  ('Kimberley Proctor',),
#  ('Mike Tyson',),
#  ('Jerry berry',),
#  ('Yuriko Du',),
#  ('Graham Sparling',),
#  ('Jeffry Warthen',),
#  ('Tish Seidman',),
#  ('Contessa Courser',),
#  ('Paul Young',),
#  ('Jerry berry',),
#  ('Kate Dagenhart',),
#  ('Dierdre Ivey',),
#  ('Frankie Haberman',),
#  ('Breana Fravel',),
#  ('Kimberley Proctor',),
#  ('Peggy Portner',),
#  ('Leila Lashley',),
#  ('Gricelda Lassen',),
#  ('Roselia Sandoz',),
#  ('Paul Young',),
#  ('Jerry berry',),
#  ('Graham Sparling',),
#  ('Wynell Griffeth',),
#  ('Meggan Seamon',),
#  ('Concha Hisle',),
#  ('Isaiah Rines',),
#  ('Mari Acy',),
#  ('Rebecka Kim',),
#  ('Gricelda Lassen',),
#  ('Maxie Chauez',),
#  ('Marty Buettner',),
#  ('Santo Yocom',),
#  ('Jerry berry',),
#  ('Kassie Pertuit',),
#  ('Yuriko Du',),
#  ('Graham Sparling',),
#  ('Tish Seidman',),
#  ('Marilynn Oxford',),
#  ('Zonia Mcknight',),
#  ('Leila Lashley',),
#  ('Francesco Roquemore',),
#  ('Angelina Brakefield',),
#  ('Brigid Mattos',),
#  ('Meggan Seamon',),
#  ('Amanda Bemis',),
#  ('Patrica Mcvay',),
#  ('Peggy Portner',),
#  ('Maxie Chauez',),
#  ('Carl Lewis',),
#  ('Vita Tores',),
#  ('Jeanetta Steenbergen',),
#  ('Timothy Kring',),
#  ('Zonia Mcknight',),
#  ('Contessa Courser',),
#  ('Dillon Lumpkins',),
#  ('Peggy Portner',),
#  ('Claretha Ahern',),
#  ('Santo Yocom',),
#  ('Carl Lewis',),
#  ('Rebbecca Tyree',),
#  ('Oralee Hilliker',),
#  ('',),
#  ('Brigid Mattos',),
#  ('',),
#  ('Oralee Hilliker',),
#  ('Winfred Yoon',),
#  ('Dierdre Ivey',),
#  ('Johnson Epting',),
#  ('',),
#  ('',),
#  ('Isaiah Rines',),
#  ('',),
#  ('',),
#  ('Kate Dagenhart',),
#  ('Dierdre Ivey',),
#  ('Jeffry Warthen',),
#  ('Brigid Mattos',),
#  ('Meggan Seamon',),
#  ('Concha Hisle',),
#  ('Kimberley Proctor',)]

# %%
# %%sql
# /* 16 Who is the manager that gets the highest bonus */
#
# SELECT Manager FROM employeesalary.`employees managers`
# JOIN employeesalary.`employees salary` ON `employees managers`.`Employee ID` = `employees salary`.`Employee ID`
# ORDER BY bonus DESC LIMIT 1;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/EmployeeSalary
# 1 rows affected.
# [('Wynell Griffeth',)]

# %%
# %%sql
# /* 17  Mention 5 contract employees who have the highest bonuses*/
#
# SELECT manager, status FROM employeesalary.`employees managers`
# JOIN employeesalary.`employees salary` ON `employees managers`.`Employee ID` = `employees salary`.`Employee ID`
# JOIN employeesalary.`employees status` ON `employees salary`.`Employee ID` = `employees status`.`Employee ID`
# WHERE status = 'contract'
# ORDER BY bonus DESC LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/EmployeeSalary
# 5 rows affected.
# [('Maxie Chauez', 'Contract'),
#  ('Frankie Haberman', 'Contract'),
#  ('Peggy Portner', 'Contract'),
#  ('Patrica Mcvay', 'Contract'),
#  ('Oralee Hilliker', 'Contract')]

# %%
# %%sql
# /* 18 How many bonuses that are unique? */
#
# SELECT COUNT(DISTINCT Bonus) AS uniqueBonuses FROM employeesalary.`employees salary`
# Out:
#  * mysql+pymysql://root:***@localhost:3306/EmployeeSalary
# 1 rows affected.
# [(9,)]

# %%
# %%sql
# /* 19 Show the projects that have been done in Washington DC */
#
# SELECT Projects AS 'projects', STATE AS 'state' FROM employeesalary.`employees salary`
# JOIN employeesalary.`employees managers` ON `employees salary`.`Employee ID` = `employees managers`.`Employee ID`
# WHERE STATE = 'WA';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/EmployeeSalary
# 208 rows affected.
# [(15, 'WA'),
#  (2, 'WA'),
#  (6, 'WA'),
#  (13, 'WA'),
#  (5, 'WA'),
#  (4, 'WA'),
#  (13, 'WA'),
#  (13, 'WA'),
#  (7, 'WA'),
#  (4, 'WA'),
#  (2, 'WA'),
#  (7, 'WA'),
#  (2, 'WA'),
#  (7, 'WA'),
#  (2, 'WA'),
#  (3, 'WA'),
#  (11, 'WA'),
#  (4, 'WA'),
#  (3, 'WA'),
#  (6, 'WA'),
#  (3, 'WA'),
#  (5, 'WA'),
#  (7, 'WA'),
#  (1, 'WA'),
#  (6, 'WA'),
#  (12, 'WA'),
#  (5, 'WA'),
#  (14, 'WA'),
#  (3, 'WA'),
#  (15, 'WA'),
#  (3, 'WA'),
#  (6, 'WA'),
#  (3, 'WA'),
#  (5, 'WA'),
#  (1, 'WA'),
#  (7, 'WA'),
#  (15, 'WA'),
#  (13, 'WA'),
#  (3, 'WA'),
#  (3, 'WA'),
#  (4, 'WA'),
#  (11, 'WA'),
#  (7, 'WA'),
#  (7, 'WA'),
#  (2, 'WA'),
#  (6, 'WA'),
#  (6, 'WA'),
#  (4, 'WA'),
#  (3, 'WA'),
#  (12, 'WA'),
#  (11, 'WA'),
#  (14, 'WA'),
#  (7, 'WA'),
#  (16, 'WA'),
#  (15, 'WA'),
#  (11, 'WA'),
#  (6, 'WA'),
#  (4, 'WA'),
#  (6, 'WA'),
#  (7, 'WA'),
#  (7, 'WA'),
#  (12, 'WA'),
#  (11, 'WA'),
#  (11, 'WA'),
#  (13, 'WA'),
#  (10, 'WA'),
#  (7, 'WA'),
#  (3, 'WA'),
#  (5, 'WA'),
#  (3, 'WA'),
#  (3, 'WA'),
#  (15, 'WA'),
#  (1, 'WA'),
#  (11, 'WA'),
#  (5, 'WA'),
#  (7, 'WA'),
#  (6, 'WA'),
#  (6, 'WA'),
#  (5, 'WA'),
#  (15, 'WA'),
#  (15, 'WA'),
#  (5, 'WA'),
#  (7, 'WA'),
#  (14, 'WA'),
#  (14, 'WA'),
#  (10, 'WA'),
#  (6, 'WA'),
#  (3, 'WA'),
#  (6, 'WA'),
#  (15, 'WA'),
#  (15, 'WA'),
#  (9, 'WA'),
#  (9, 'WA'),
#  (5, 'WA'),
#  (3, 'WA'),
#  (2, 'WA'),
#  (7, 'WA'),
#  (12, 'WA'),
#  (2, 'WA'),
#  (6, 'WA'),
#  (7, 'WA'),
#  (15, 'WA'),
#  (14, 'WA'),
#  (14, 'WA'),
#  (3, 'WA'),
#  (3, 'WA'),
#  (7, 'WA'),
#  (12, 'WA'),
#  (12, 'WA'),
#  (13, 'WA'),
#  (3, 'WA'),
#  (3, 'WA'),
#  (10, 'WA'),
#  (15, 'WA'),
#  (1, 'WA'),
#  (15, 'WA'),
#  (3, 'WA'),
#  (7, 'WA'),
#  (15, 'WA'),
#  (6, 'WA'),
#  (15, 'WA'),
#  (14, 'WA'),
#  (13, 'WA'),
#  (9, 'WA'),
#  (1, 'WA'),
#  (1, 'WA'),
#  (3, 'WA'),
#  (3, 'WA'),
#  (3, 'WA'),
#  (5, 'WA'),
#  (2, 'WA'),
#  (2, 'WA'),
#  (5, 'WA'),
#  (14, 'WA'),
#  (1, 'WA'),
#  (1, 'WA'),
#  (4, 'WA'),
#  (1, 'WA'),
#  (3, 'WA'),
#  (2, 'WA'),
#  (5, 'WA'),
#  (15, 'WA'),
#  (6, 'WA'),
#  (3, 'WA'),
#  (15, 'WA'),
#  (6, 'WA'),
#  (7, 'WA'),
#  (3, 'WA'),
#  (6, 'WA'),
#  (7, 'WA'),
#  (13, 'WA'),
#  (3, 'WA'),
#  (5, 'WA'),
#  (2, 'WA'),
#  (2, 'WA'),
#  (2, 'WA'),
#  (5, 'WA'),
#  (4, 'WA'),
#  (2, 'WA'),
#  (6, 'WA'),
#  (16, 'WA'),
#  (14, 'WA'),
#  (6, 'WA'),
#  (15, 'WA'),
#  (14, 'WA'),
#  (7, 'WA'),
#  (6, 'WA'),
#  (15, 'WA'),
#  (13, 'WA'),
#  (2, 'WA'),
#  (15, 'WA'),
#  (7, 'WA'),
#  (9, 'WA'),
#  (1, 'WA'),
#  (3, 'WA'),
#  (15, 'WA'),
#  (15, 'WA'),
#  (14, 'WA'),
#  (14, 'WA'),
#  (3, 'WA'),
#  (3, 'WA'),
#  (7, 'WA'),
#  (14, 'WA'),
#  (3, 'WA'),
#  (2, 'WA'),
#  (2, 'WA'),
#  (7, 'WA'),
#  (2, 'WA'),
#  (6, 'WA'),
#  (6, 'WA'),
#  (14, 'WA'),
#  (12, 'WA'),
#  (5, 'WA'),
#  (3, 'WA'),
#  (3, 'WA'),
#  (15, 'WA'),
#  (5, 'WA'),
#  (2, 'WA'),
#  (2, 'WA'),
#  (2, 'WA'),
#  (1, 'WA'),
#  (13, 'WA'),
#  (7, 'WA'),
#  (6, 'WA'),
#  (3, 'WA'),
#  (10, 'WA'),
#  (12, 'WA'),
#  (3, 'WA')]

# %%
# %%sql
# /* 20 How many halftime versus fulltime employees are there? */
#
# SELECT COUNT(Status) FROM employeesalary.`employees status`
# WHERE Status = 'Full Time' & 'Half-Time';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/EmployeeSalary
# 1 rows affected.
# [(741,)]

# %%
# %%sql
# /* 21 How many employees are there in status category */
#
# SELECT Status, COUNT(status) AS employeeNumber FROM employeesalary.`employees status`
# GROUP BY status;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/EmployeeSalary
# 5 rows affected.
# [('Full Time', 358),
#  ('Half-Time', 87),
#  ('Contract', 186),
#  ('Hourly', 47),
#  ('', 63)]
